# %% [markdown]
# 卷积层：把图像变成0-1之间的数据矩阵，提取图像的特征
# 池化层：把数据矩阵变成更小的矩阵，将特征提取到最突出的元素
# 全连接层：把数据矩阵变成一维向量，用于分类或回归
# 基本架构：Inputs按照Weights输入到Summation and Bias然后输入Activation最后输出Output
# 卷积是一种线性运算：将一种权重和输入相乘，用来捕获边缘，颜色，形状等基本特征，伴随卷积层的增高可以提取更高级的特征
# 池化层能逐渐缩小表示的空间大小，单独对每个特征图进行运算，常用最大池化，捕捉数组的最大值
